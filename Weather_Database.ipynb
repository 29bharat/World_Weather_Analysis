# %%
# Import the random module.
import random

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 613

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a64c796d97ed68b62f3c37ff8fa4295d

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_currentweather = city_weather["weather"][0]["description"]
        try:
            city_rain = city_weather["rain"]["3h"]
        except KeyError :
            city_rain = 0
        try:
            city_snow = city_weather["snow"]["3h"]
        except KeyError:
            city_snow = 0
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_currentweather,
                          "Rain Inches (last 3 hrs)": city_rain,
                          "Snow Inches (last 3 hrs)": city_snow,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 13 | thompson
# Processing Record 2 of Set 13 | busselton
# Processing Record 3 of Set 13 | rio grande
# Processing Record 4 of Set 13 | rikitea
# Processing Record 5 of Set 13 | mataura
# Processing Record 6 of Set 13 | punta arenas
# Processing Record 7 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 13 | hammerfest
# Processing Record 9 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 13 | southbridge
# Processing Record 11 of Set 13 | fare
# Processing Record 12 of Set 13 | otradinskiy
# City not found. Skipping...
# Processing Record 13 of Set 13 | itoman
# Processing Record 14 of Set 13 | ixtapa
# Processing Record 15 of Set 13 | ribeira grande
# Processing Record 16 of Set 13 | ullapool
# Processing Record 17 of Set 13 | cayenne
# Processing Record 18 of Set 13 | naron
# Processing Record 19 of Set 13 | hovd
# Processing Record 20 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 21 of Set 13 | kaspiyskiy
# Processing Record 22 of Set 13 | kavieng
# Processing Record 23 of Set 13 | wattwil
# Processing Record 24 of Set 13 | puerto ayora
# Processing Record 25 of Set 13 | helsingborg
# Processing Record 26 of Set 13 | hermanus
# Processing Record 27 of Set 13 | castro
# Processing Record 28 of Set 13 | abeche
# Processing Record 29 of Set 13 | kankon
# Processing Record 30 of Set 13 | atuona
# Processing Record 31 of Set 13 | vao
# Processing Record 32 of Set 13 | khandyga
# Processing Record 33 of Set 13 | porto santo
# Processing Record 34 of Set 13 | bredasdorp
# Processing Record 35 of Set 13 | port elizabeth
# Processing Record 36 of Set 13 | isangel
# Processing Record 37 of Set 13 | tunceli
# Processing Record 38 of Set 13 | sebring
# Processing Record 39 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 13 | cape town
# Processing Record 41 of Set 13 | broken hill
# Processing Record 42 of Set 13 | albany
# Processing Record 43 of Set 13 | hofn
# Processing Record 44 of Set 13 | bambous virieux
# Processing Record 45 of Set 13 | teguise
# Processing Record 46 of Set 13 | asau
# Processing Record 47 of Set 13 | ulladulla
# Processing Record 48 of Set 13 | atambua
# Processing Record 49 of Set 13 | boguchany
# Processing Record 50 of Set 13 | barrow
# Processing Record 1 of Set 14 | chokurdakh
# Processing Record 2 of Set 14 | port blair
# Processing Record 3 of Set 14 | lebu
# Processing Record 4 of Set 14 | weligama
# Processing Record 5 of Set 14 | avarua
# Processing Record 6 of Set 14 | salekhard
# Processing Record 7 of Set 14 | tasiilaq
# Processing Record 8 of Set 14 | saint-philippe
# Processing Record 9 of Set 14 | tigre
# Processing Record 10 of Set 14 | jalu
# Processing Record 11 of Set 14 | tual
# Processing Record 12 of Set 14 | rostaq
# City not found. Skipping...
# Processing Record 13 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 14 | marzuq
# Processing Record 15 of Set 14 | esna
# Processing Record 16 of Set 14 | itarema
# Processing Record 17 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 14 | carnarvon
# Processing Record 19 of Set 14 | cooma
# Processing Record 20 of Set 14 | kirakira
# Processing Record 21 of Set 14 | salihorsk
# Processing Record 22 of Set 14 | port alfred
# Processing Record 23 of Set 14 | lorengau
# Processing Record 24 of Set 14 | cloppenburg
# Processing Record 25 of Set 14 | georgetown
# Processing Record 26 of Set 14 | nikolskoye
# Processing Record 27 of Set 14 | tura
# Processing Record 28 of Set 14 | tuktoyaktuk
# Processing Record 29 of Set 14 | belokurikha
# Processing Record 30 of Set 14 | toyooka
# Processing Record 31 of Set 14 | shingu
# Processing Record 32 of Set 14 | antalaha
# Processing Record 33 of Set 14 | hondo
# Processing Record 34 of Set 14 | boa vista
# Processing Record 35 of Set 14 | atar
# Processing Record 36 of Set 14 | leh
# Processing Record 37 of Set 14 | tacoronte
# Processing Record 38 of Set 14 | bluff
# Processing Record 39 of Set 14 | ciudad bolivar
# Processing Record 40 of Set 14 | cape coast
# Processing Record 41 of Set 14 | pangnirtung
# Processing Record 42 of Set 14 | codrington
# Processing Record 43 of Set 14 | arandis
# Processing Record 44 of Set 14 | ushuaia
# Processing Record 45 of Set 14 | hvolsvollur
# Processing Record 46 of Set 14 | kongolo
# Processing Record 47 of Set 14 | bubaque
# Processing Record 48 of Set 14 | kloulklubed
# Processing Record 49 of Set 14 | butaritari
# Processing Record 50 of Set 14 | vaini
# Processing Record 1 of Set 15 | ambon
# Processing Record 2 of Set 15 | coquimbo
# Processing Record 3 of Set 15 | porto velho
# Processing Record 4 of Set 15 | yellowknife
# Processing Record 5 of Set 15 | cidreira
# Processing Record 6 of Set 15 | souillac
# Processing Record 7 of Set 15 | tiksi
# Processing Record 8 of Set 15 | taoudenni
# Processing Record 9 of Set 15 | port lincoln
# Processing Record 10 of Set 15 | aklavik
# Processing Record 11 of Set 15 | new norfolk
# Processing Record 12 of Set 15 | uzunkopru
# City not found. Skipping...
# Processing Record 13 of Set 15 | broome
# Processing Record 14 of Set 15 | mayo
# Processing Record 15 of Set 15 | santa maria
# Processing Record 16 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 17 of Set 15 | yabrud
# Processing Record 18 of Set 15 | hilo
# Processing Record 19 of Set 15 | komsomolskiy
# Processing Record 20 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 21 of Set 15 | airai
# Processing Record 22 of Set 15 | jamestown
# Processing Record 23 of Set 15 | buraydah
# Processing Record 24 of Set 15 | razvilnoye
# Processing Record 25 of Set 15 | formosa
# Processing Record 26 of Set 15 | chapais
# Processing Record 27 of Set 15 | suntar
# Processing Record 28 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 15 | ostrovnoy
# Processing Record 30 of Set 15 | udayagiri
# Processing Record 31 of Set 15 | kilinochchi
# Processing Record 32 of Set 15 | dikson
# Processing Record 33 of Set 15 | kaitangata
# Processing Record 34 of Set 15 | alihe
# Processing Record 35 of Set 15 | upernavik
# Processing Record 36 of Set 15 | morki
# Processing Record 37 of Set 15 | namatanai
# Processing Record 38 of Set 15 | qaanaaq
# Processing Record 39 of Set 15 | pangkalanbuun
# Processing Record 40 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 15 | north bend
# Processing Record 42 of Set 15 | fort nelson
# Processing Record 43 of Set 15 | inuvik
# Processing Record 44 of Set 15 | abhar
# Processing Record 45 of Set 15 | ponta do sol
# Processing Record 46 of Set 15 | luderitz
# Processing Record 47 of Set 15 | rovaniemi
# Processing Record 48 of Set 15 | ahipara
# Processing Record 49 of Set 15 | naze
# Processing Record 50 of Set 15 | kargil
# Processing Record 1 of Set 16 | hithadhoo
# Processing Record 2 of Set 16 | dalvik
# Processing Record 3 of Set 16 | issaquah
# Processing Record 4 of Set 16 | torbay
# Processing Record 5 of Set 16 | chuy
# Processing Record 6 of Set 16 | alofi
# Processing Record 7 of Set 16 | ayr
# Processing Record 8 of Set 16 | port shepstone
# Processing Record 9 of Set 16 | nouadhibou
# Processing Record 10 of Set 16 | lasa
# Processing Record 11 of Set 16 | mehamn
# Processing Record 12 of Set 16 | bethel
# Processing Record 13 of Set 16 | katsuura
# Processing Record 14 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 16 | fortuna
# Processing Record 16 of Set 16 | saint george
# Processing Record 17 of Set 16 | terney
# Processing Record 18 of Set 16 | san cristobal
# Processing Record 19 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 16 | jacareacanga
# Processing Record 21 of Set 16 | flinders
# Processing Record 22 of Set 16 | udalguri
# Processing Record 23 of Set 16 | viedma
# Processing Record 24 of Set 16 | yamoussoukro
# Processing Record 25 of Set 16 | lyngseidet
# Processing Record 26 of Set 16 | sayyan
# Processing Record 27 of Set 16 | kaliganj
# Processing Record 28 of Set 16 | mohgaon
# Processing Record 29 of Set 16 | mudyuga
# City not found. Skipping...
# Processing Record 30 of Set 16 | alice springs
# Processing Record 31 of Set 16 | asyut
# Processing Record 32 of Set 16 | sackville
# Processing Record 33 of Set 16 | rocky mountain house
# Processing Record 34 of Set 16 | najran
# Processing Record 35 of Set 16 | faya
# Processing Record 36 of Set 16 | tuatapere
# Processing Record 37 of Set 16 | chernyshevskiy
# Processing Record 38 of Set 16 | kozienice
# Processing Record 39 of Set 16 | hobart
# Processing Record 40 of Set 16 | hamilton
# Processing Record 41 of Set 16 | ancud
# Processing Record 42 of Set 16 | bengkulu
# Processing Record 43 of Set 16 | ovalle
# Processing Record 44 of Set 16 | todos santos
# Processing Record 45 of Set 16 | kapaa
# Processing Record 46 of Set 16 | nanhai
# Processing Record 47 of Set 16 | luxor
# Processing Record 48 of Set 16 | vallenar
# Processing Record 49 of Set 16 | miri
# Processing Record 50 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 17 | mayumba
# Processing Record 2 of Set 17 | usila
# City not found. Skipping...
# Processing Record 3 of Set 17 | avera
# Processing Record 4 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 17 | lokomotivnyy
# Processing Record 6 of Set 17 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 17 | matara
# Processing Record 8 of Set 17 | thessalon
# Processing Record 9 of Set 17 | fort saint james
# Processing Record 10 of Set 17 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 17 | pisco
# Processing Record 12 of Set 17 | gwadar
# Processing Record 13 of Set 17 | la ronge
# Processing Record 14 of Set 17 | deputatskiy
# Processing Record 15 of Set 17 | bac lieu
# Processing Record 16 of Set 17 | williston
# Processing Record 17 of Set 17 | puerto escondido
# Processing Record 18 of Set 17 | butembo
# Processing Record 19 of Set 17 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 17 | kodiak
# Processing Record 21 of Set 17 | rizhao
# Processing Record 22 of Set 17 | longyearbyen
# Processing Record 23 of Set 17 | biak
# Processing Record 24 of Set 17 | sistranda
# Processing Record 25 of Set 17 | dera din panah
# City not found. Skipping...
# Processing Record 26 of Set 17 | iqaluit
# Processing Record 27 of Set 17 | mocuba
# Processing Record 28 of Set 17 | cherskiy
# Processing Record 29 of Set 17 | karakendzha
# City not found. Skipping...
# Processing Record 30 of Set 17 | lokosovo
# Processing Record 31 of Set 17 | pauini
# Processing Record 32 of Set 17 | fairbanks
# Processing Record 33 of Set 17 | walvis bay
# Processing Record 34 of Set 17 | egvekinot
# Processing Record 35 of Set 17 | ormara
# Processing Record 36 of Set 17 | odweyne
# Processing Record 37 of Set 17 | ningan
# City not found. Skipping...
# Processing Record 38 of Set 17 | port hedland
# Processing Record 39 of Set 17 | te anau
# Processing Record 40 of Set 17 | bur gabo
# City not found. Skipping...
# Processing Record 41 of Set 17 | mugumu
# Processing Record 42 of Set 17 | cocobeach
# Processing Record 43 of Set 17 | moron
# Processing Record 44 of Set 17 | sao filipe
# Processing Record 45 of Set 17 | mount gambier
# Processing Record 46 of Set 17 | constitucion
# Processing Record 47 of Set 17 | chengde
# Processing Record 48 of Set 17 | paralimni
# Processing Record 49 of Set 17 | lucea
# Processing Record 50 of Set 17 | salalah
# Processing Record 1 of Set 18 | saskylakh
# Processing Record 2 of Set 18 | berdigestyakh
# Processing Record 3 of Set 18 | kiama
# Processing Record 4 of Set 18 | zonguldak
# Processing Record 5 of Set 18 | tiarei
# Processing Record 6 of Set 18 | basco
# Processing Record 7 of Set 18 | ilulissat
# Processing Record 8 of Set 18 | boddam
# Processing Record 9 of Set 18 | khatanga
# Processing Record 10 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 18 | nanortalik
# Processing Record 12 of Set 18 | sao felipe
# Processing Record 13 of Set 18 | san quintin
# Processing Record 14 of Set 18 | dekar
# Processing Record 15 of Set 18 | sompeta
# Processing Record 16 of Set 18 | berlevag
# Processing Record 17 of Set 18 | tigil
# Processing Record 18 of Set 18 | yar-sale
# Processing Record 19 of Set 18 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of Set 18 | guasdualito
# Processing Record 21 of Set 18 | chiang klang
# Processing Record 22 of Set 18 | leeton
# Processing Record 23 of Set 18 | gurskoye
# City not found. Skipping...
# Processing Record 24 of Set 18 | copiapo
# Processing Record 25 of Set 18 | sioux lookout
# Processing Record 26 of Set 18 | port-gentil
# Processing Record 27 of Set 18 | cabo san lucas
# Processing Record 28 of Set 18 | benalla
# Processing Record 29 of Set 18 | vardo
# Processing Record 30 of Set 18 | okhotsk
# Processing Record 31 of Set 18 | dingle
# Processing Record 32 of Set 18 | leningradskiy
# Processing Record 33 of Set 18 | lyaskelya
# Processing Record 34 of Set 18 | baykit
# Processing Record 35 of Set 18 | yangambi
# Processing Record 36 of Set 18 | poum
# Processing Record 37 of Set 18 | sitka
# Processing Record 38 of Set 18 | umtata
# Processing Record 39 of Set 18 | phangnga
# Processing Record 40 of Set 18 | anloga
# Processing Record 41 of Set 18 | bilma
# Processing Record 42 of Set 18 | touros
# Processing Record 43 of Set 18 | clyde river
# Processing Record 44 of Set 18 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 18 | port macquarie
# Processing Record 46 of Set 18 | thinadhoo
# Processing Record 47 of Set 18 | myitkyina
# Processing Record 48 of Set 18 | talnakh
# Processing Record 49 of Set 18 | ponta delgada
# Processing Record 50 of Set 18 | qui nhon
# Processing Record 1 of Set 19 | mumford
# Processing Record 2 of Set 19 | gamba
# Processing Record 3 of Set 19 | college
# Processing Record 4 of Set 19 | hokitika
# Processing Record 5 of Set 19 | pahrump
# Processing Record 6 of Set 19 | tabialan
# City not found. Skipping...
# Processing Record 7 of Set 19 | norman wells
# Processing Record 8 of Set 19 | manaira
# Processing Record 9 of Set 19 | bandarbeyla
# Processing Record 10 of Set 19 | turochak
# Processing Record 11 of Set 19 | ngunguru
# Processing Record 12 of Set 19 | cabo rojo
# Processing Record 13 of Set 19 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 19 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 19 | springbok
# Processing Record 16 of Set 19 | oranjemund
# Processing Record 17 of Set 19 | awbari
# Processing Record 18 of Set 19 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 19 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 19 | svetlogorsk
# Processing Record 21 of Set 19 | kawana waters
# City not found. Skipping...
# Processing Record 22 of Set 19 | taltal
# Processing Record 23 of Set 19 | omboue
# Processing Record 24 of Set 19 | itacoatiara
# Processing Record 25 of Set 19 | khanapur
# Processing Record 26 of Set 19 | houma
# Processing Record 27 of Set 19 | amapa
# Processing Record 28 of Set 19 | pinsk
# Processing Record 29 of Set 19 | lompoc
# Processing Record 30 of Set 19 | padang
# Processing Record 31 of Set 19 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 19 | srednekolymsk
# Processing Record 33 of Set 19 | marfino
# Processing Record 34 of Set 19 | faanui
# Processing Record 35 of Set 19 | drumheller
# Processing Record 36 of Set 19 | mar del plata
# Processing Record 37 of Set 19 | zarubino
# Processing Record 38 of Set 19 | qeshm
# Processing Record 39 of Set 19 | grindavik
# Processing Record 40 of Set 19 | kashan
# Processing Record 41 of Set 19 | umiray
# Processing Record 42 of Set 19 | kondinskoye
# Processing Record 43 of Set 19 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 19 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 19 | peniche
# Processing Record 46 of Set 19 | yidu
# Processing Record 47 of Set 19 | kailua
# Processing Record 48 of Set 19 | mahebourg
# Processing Record 49 of Set 19 | morondava
# Processing Record 50 of Set 19 | west wendover
# Processing Record 1 of Set 20 | victoria
# Processing Record 2 of Set 20 | olonets
# Processing Record 3 of Set 20 | srandakan
# Processing Record 4 of Set 20 | hope
# Processing Record 5 of Set 20 | mataram
# Processing Record 6 of Set 20 | namibe
# Processing Record 7 of Set 20 | jackson
# Processing Record 8 of Set 20 | aripuana
# Processing Record 9 of Set 20 | nantucket
# Processing Record 10 of Set 20 | muskegon
# Processing Record 11 of Set 20 | merauke
# Processing Record 12 of Set 20 | talaya
# Processing Record 13 of Set 20 | borjomi
# Processing Record 14 of Set 20 | rock springs
# Processing Record 15 of Set 20 | haines junction
# Processing Record 16 of Set 20 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 20 | manggar
# Processing Record 18 of Set 20 | singaraja
# Processing Record 19 of Set 20 | belmonte
# Processing Record 20 of Set 20 | inta
# Processing Record 21 of Set 20 | emba
# Processing Record 22 of Set 20 | nelson bay
# Processing Record 23 of Set 20 | margate
# Processing Record 24 of Set 20 | marrakesh
# Processing Record 25 of Set 20 | vysokogornyy
# Processing Record 26 of Set 20 | mecca
# Processing Record 27 of Set 20 | mitsamiouli
# Processing Record 28 of Set 20 | severo-kurilsk
# Processing Record 29 of Set 20 | dunedin
# Processing Record 30 of Set 20 | mabaruma
# Processing Record 31 of Set 20 | cervo
# Processing Record 32 of Set 20 | haibowan
# City not found. Skipping...
# Processing Record 33 of Set 20 | boueni
# Processing Record 34 of Set 20 | raymond
# Processing Record 35 of Set 20 | portland
# Processing Record 36 of Set 20 | puerto el triunfo
# Processing Record 37 of Set 20 | moose factory
# Processing Record 38 of Set 20 | montrose
# Processing Record 39 of Set 20 | grand-santi
# Processing Record 40 of Set 20 | bambanglipuro
# Processing Record 41 of Set 20 | bonavista
# Processing Record 42 of Set 20 | hanmer springs
# Processing Record 43 of Set 20 | saint-francois
# Processing Record 44 of Set 20 | vereshchagino
# Processing Record 45 of Set 20 | qaqortoq
# Processing Record 46 of Set 20 | christchurch
# Processing Record 47 of Set 20 | galesong
# Processing Record 48 of Set 20 | tygda
# Processing Record 49 of Set 20 | mbarara
# Processing Record 50 of Set 20 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 21 | arraial do cabo
# Processing Record 2 of Set 21 | belen
# Processing Record 3 of Set 21 | nyzhni sirohozy
# Processing Record 4 of Set 21 | karratha
# Processing Record 5 of Set 21 | chepo
# Processing Record 6 of Set 21 | port hardy
# Processing Record 7 of Set 21 | geraldton
# Processing Record 8 of Set 21 | mariakani
# Processing Record 9 of Set 21 | san matias
# Processing Record 10 of Set 21 | naryan-mar
# Processing Record 11 of Set 21 | guajara-mirim
# City not found. Skipping...
# Processing Record 12 of Set 21 | axim
# Processing Record 13 of Set 21 | voh
# Processing Record 14 of Set 21 | linapacan
# City not found. Skipping...
# Processing Record 15 of Set 21 | mount pleasant
# Processing Record 16 of Set 21 | chuguyevka
# Processing Record 17 of Set 21 | osorheiu
# Processing Record 18 of Set 21 | muscat
# Processing Record 19 of Set 21 | bahia honda
# Processing Record 20 of Set 21 | whyalla
# Processing Record 21 of Set 21 | derzhavinsk
# Processing Record 22 of Set 21 | kununurra
# Processing Record 23 of Set 21 | vanavara
# Processing Record 24 of Set 21 | rivarolo canavese
# Processing Record 25 of Set 21 | trairi
# Processing Record 26 of Set 21 | san patricio
# Processing Record 27 of Set 21 | kaffrine
# Processing Record 28 of Set 21 | kagawasan
# Processing Record 29 of Set 21 | paredon
# Processing Record 30 of Set 21 | gat
# Processing Record 31 of Set 21 | buala
# Processing Record 32 of Set 21 | esperance
# Processing Record 33 of Set 21 | ibra
# Processing Record 34 of Set 21 | tucuman
# Processing Record 35 of Set 21 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 21 | las vegas
# Processing Record 37 of Set 21 | east london
# Processing Record 38 of Set 21 | ginda
# Processing Record 39 of Set 21 | minab
# Processing Record 40 of Set 21 | alberton
# Processing Record 41 of Set 21 | gizo
# Processing Record 42 of Set 21 | orbetello
# Processing Record 43 of Set 21 | chino valley
# Processing Record 44 of Set 21 | osmena
# Processing Record 45 of Set 21 | birin
# Processing Record 46 of Set 21 | kharagauli
# Processing Record 47 of Set 21 | adrar
# Processing Record 48 of Set 21 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 21 | ialibu
# Processing Record 50 of Set 21 | katherine
# Processing Record 1 of Set 22 | jinchengjiang
# City not found. Skipping...
# Processing Record 2 of Set 22 | labuan
# Processing Record 3 of Set 22 | saldanha
# Processing Record 4 of Set 22 | kulhudhuffushi
# Processing Record 5 of Set 22 | jinji
# Processing Record 6 of Set 22 | alibag
# Processing Record 7 of Set 22 | rio gallegos
# Processing Record 8 of Set 22 | aban
# Processing Record 9 of Set 22 | maputo
# Processing Record 10 of Set 22 | conde
# Processing Record 11 of Set 22 | dogondoutchi
# Processing Record 12 of Set 22 | bima
# Processing Record 13 of Set 22 | tabuk
# Processing Record 14 of Set 22 | redcliffe
# Processing Record 15 of Set 22 | luganville
# Processing Record 16 of Set 22 | lagoa
# Processing Record 17 of Set 22 | salinas
# Processing Record 18 of Set 22 | tocopilla
# Processing Record 19 of Set 22 | saint-augustin
# Processing Record 20 of Set 22 | puerto suarez
# Processing Record 21 of Set 22 | ochamchira
# Processing Record 22 of Set 22 | ji-parana
# City not found. Skipping...
# Processing Record 23 of Set 22 | pushkino
# Processing Record 24 of Set 22 | jibuti
# Processing Record 25 of Set 22 | cairns
# Processing Record 26 of Set 22 | storm lake
# Processing Record 27 of Set 22 | edgewater
# Processing Record 28 of Set 22 | hobyo
# Processing Record 29 of Set 22 | provideniya
# Processing Record 30 of Set 22 | bose
# Processing Record 31 of Set 22 | kabalo
# Processing Record 32 of Set 22 | bruiu
# Processing Record 33 of Set 22 | bemidji
# Processing Record 34 of Set 22 | puerto leguizamo
# Processing Record 35 of Set 22 | sibolga
# Processing Record 36 of Set 22 | valparaiso
# Processing Record 37 of Set 22 | mazagao
# Processing Record 38 of Set 22 | hasaki
# Processing Record 39 of Set 22 | solnechnyy
# Processing Record 40 of Set 22 | muli
# Processing Record 41 of Set 22 | garachine
# Processing Record 42 of Set 22 | luanda
# Processing Record 43 of Set 22 | rodrigues alves
# Processing Record 44 of Set 22 | estreito
# Processing Record 45 of Set 22 | simplicio mendes
# Processing Record 46 of Set 22 | nara
# Processing Record 47 of Set 22 | sorland
# Processing Record 48 of Set 22 | cardston
# Processing Record 49 of Set 22 | hurghada
# Processing Record 50 of Set 22 | thamaga
# Processing Record 1 of Set 23 | bulgan
# Processing Record 2 of Set 23 | half moon bay
# Processing Record 3 of Set 23 | klaksvik
# Processing Record 4 of Set 23 | vrangel
# Processing Record 5 of Set 23 | pacific grove
# Processing Record 6 of Set 23 | laredo
# Processing Record 7 of Set 23 | pevek
# Processing Record 8 of Set 23 | pustoshka
# Processing Record 9 of Set 23 | guicheng
# City not found. Skipping...
# Processing Record 10 of Set 23 | jatai
# Processing Record 11 of Set 23 | ballina
# Processing Record 12 of Set 23 | kahului
# Processing Record 13 of Set 23 | inverell
# Processing Record 14 of Set 23 | tessaoua
# Processing Record 15 of Set 23 | gambela
# Processing Record 16 of Set 23 | artyk
# City not found. Skipping...
# Processing Record 17 of Set 23 | richards bay
# Processing Record 18 of Set 23 | bukene
# Processing Record 19 of Set 23 | umm durman
# City not found. Skipping...
# Processing Record 20 of Set 23 | karkaralinsk
# City not found. Skipping...
# Processing Record 21 of Set 23 | marshall
# Processing Record 22 of Set 23 | samarai
# Processing Record 23 of Set 23 | qingan
# City not found. Skipping...
# Processing Record 24 of Set 23 | callaway
# Processing Record 25 of Set 23 | riviere-au-renard
# Processing Record 26 of Set 23 | olenino
# Processing Record 27 of Set 23 | malpe
# Processing Record 28 of Set 23 | akyab
# Processing Record 29 of Set 23 | aksarka
# Processing Record 30 of Set 23 | mangai
# Processing Record 31 of Set 23 | acarau
# Processing Record 32 of Set 23 | maceio
# Processing Record 33 of Set 23 | sinnamary
# Processing Record 34 of Set 23 | las palmas
# Processing Record 35 of Set 23 | hami
# Processing Record 36 of Set 23 | pyay
# Processing Record 37 of Set 23 | roald
# Processing Record 38 of Set 23 | opobo
# City not found. Skipping...
# Processing Record 39 of Set 23 | fukue
# Processing Record 40 of Set 23 | chicama
# Processing Record 41 of Set 23 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 23 | los llanos de aridane
# Processing Record 43 of Set 23 | kyren
# Processing Record 44 of Set 23 | pouembout
# Processing Record 45 of Set 23 | manzanillo
# Processing Record 46 of Set 23 | takoradi
# Processing Record 47 of Set 23 | cap malheureux
# Processing Record 48 of Set 23 | xifeng
# Processing Record 49 of Set 23 | mahibadhoo
# Processing Record 50 of Set 23 | ikom
# Processing Record 1 of Set 24 | comodoro rivadavia
# Processing Record 2 of Set 24 | tondano
# Processing Record 3 of Set 24 | gornyak
# Processing Record 4 of Set 24 | yerbogachen
# Processing Record 5 of Set 24 | tubuala
# Processing Record 6 of Set 24 | maraa
# Processing Record 7 of Set 24 | acari
# Processing Record 8 of Set 24 | aykino
# Processing Record 9 of Set 24 | gweta
# Processing Record 10 of Set 24 | sabang
# Processing Record 11 of Set 24 | plouzane
# Processing Record 12 of Set 24 | hoquiam
# Processing Record 13 of Set 24 | san felipe
# Processing Record 14 of Set 24 | san pedro
# Processing Record 15 of Set 24 | orgun
# City not found. Skipping...
# Processing Record 16 of Set 24 | birao
# Processing Record 17 of Set 24 | mende
# Processing Record 18 of Set 24 | sisimiut
# Processing Record 19 of Set 24 | yakymivka
# Processing Record 20 of Set 24 | wanaka
# Processing Record 21 of Set 24 | paramonga
# Processing Record 22 of Set 24 | lenger
# Processing Record 23 of Set 24 | kanash
# Processing Record 24 of Set 24 | alamosa
# Processing Record 25 of Set 24 | lodeynoye pole
# Processing Record 26 of Set 24 | celestun
# Processing Record 27 of Set 24 | sao borja
# Processing Record 28 of Set 24 | karabuk
# Processing Record 29 of Set 24 | kyabe
# Processing Record 30 of Set 24 | queanbeyan
# Processing Record 31 of Set 24 | ratnagiri
# Processing Record 32 of Set 24 | dengzhou
# Processing Record 33 of Set 24 | redmond
# Processing Record 34 of Set 24 | zapolyarnyy
# Processing Record 35 of Set 24 | mount isa
# Processing Record 36 of Set 24 | ca mau
# Processing Record 37 of Set 24 | mandiana
# Processing Record 38 of Set 24 | altay
# Processing Record 39 of Set 24 | sandakan
# Processing Record 40 of Set 24 | litovko
# Processing Record 41 of Set 24 | pemberton
# Processing Record 42 of Set 24 | nome
# Processing Record 43 of Set 24 | the valley
# Processing Record 44 of Set 24 | kovur
# Processing Record 45 of Set 24 | eureka
# Processing Record 46 of Set 24 | marienburg
# Processing Record 47 of Set 24 | panguna
# Processing Record 48 of Set 24 | changde
# Processing Record 49 of Set 24 | brejo da madre de deus
# Processing Record 50 of Set 24 | novopavlovka
# Processing Record 1 of Set 25 | waingapu
# Processing Record 2 of Set 25 | skibbereen
# Processing Record 3 of Set 25 | tahoua
# Processing Record 4 of Set 25 | omsukchan
# Processing Record 5 of Set 25 | guarapari
# Processing Record 6 of Set 25 | yumen
# Processing Record 7 of Set 25 | rio bravo
# Processing Record 8 of Set 25 | hazorasp
# Processing Record 9 of Set 25 | helena
# Processing Record 10 of Set 25 | chacabuco
# Processing Record 11 of Set 25 | dhidhdhoo
# Processing Record 12 of Set 25 | manono
# Processing Record 13 of Set 25 | vestmannaeyjar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 557

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Thompson  55.74  -97.86     14.00        66          90
# 1         Busselton -33.65  115.33     68.00        44          93
# 2        Rio Grande -32.03  -52.10     78.80        47          20
# 3           Rikitea -23.12 -134.97     78.37        74           2
# 4           Mataura -46.19  168.86     51.01        92          93
# ..              ...    ...     ...       ...       ...         ...
# 552          Helena  46.59 -112.04     35.60        55           1
# 553       Chacabuco -34.64  -60.47     75.00        58          36
# 554       Dhidhdhoo   6.88   73.10     82.22        77          43
# 555          Manono  -7.30   27.42     73.58        94         100
# 556  Vestmannaeyjar  63.44  -20.27     33.80        63          75
#
#      Wind Speed Country Current Description  Rain Inches (last 3 hrs)  \
# 0          5.82      CA     overcast clouds                      0.00
# 1         15.14      AU          light rain                      0.69
# 2         17.22      BR          few clouds                      0.00
# 3          8.25      PF          light rain                      0.44
# 4          3.00      NZ     overcast clouds                      0.00
# ..          ...     ...                 ...                       ...
# 552        3.36      US           clear sky                      0.00
# 553        4.00      AR    scattered clouds                      0.00
# 554        9.75      MV    scattered clouds                      0.00
# 555        3.58      CD          light rain                      1.88
# 556       34.45      IS         shower rain                      0.00
#
#      Snow Inches (last 3 hrs)                 Date
# 0                         0.0  2020-02-23 18:40:10
# 1                         0.0  2020-02-23 18:40:44
# 2                         0.0  2020-02-23 18:49:01
# 3                         0.0  2020-02-23 18:40:23
# 4                         0.0  2020-02-23 18:40:31
# ..                        ...                  ...
# 552                       0.0  2020-02-23 18:50:36
# 553                       0.0  2020-02-23 18:51:11
# 554                       0.0  2020-02-23 18:45:16
# 555                       0.0  2020-02-23 18:51:11
# 556                       0.0  2020-02-23 18:51:11
#
# [557 rows x 12 columns]

# %%
rain_count=city_data_df.loc[city_data_df["Rain Inches (last 3 hrs)"]>0, ["Rain Inches (last 3 hrs)"]].count()
snow_count=city_data_df.loc[city_data_df["Snow Inches (last 3 hrs)"]>0, ["Snow Inches (last 3 hrs)"]].count()
print(f'rain count:{rain_count},snow count:{snow_count}')
# Out:
# rain count:Rain Inches (last 3 hrs)    65
# dtype: int64,snow count:Snow Inches (last 3 hrs)    25
# dtype: int64

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_challenge.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
new_col_ord = ["City", "Country","Date", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description","Rain Inches (last 3 hrs)", "Snow Inches (last 3 hrs)"]
city_data_df = city_data_df[new_col_ord]
