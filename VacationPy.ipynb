# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID            City Country                 Date    Lat     Lng  \
# 0        0           Arlit      NE  2020-02-21 06:50:16  18.74    7.39
# 1        1         Ushuaia      AR  2020-02-21 06:50:17 -54.80  -68.30
# 2        2       Carnarvon      AU  2020-02-21 06:50:17 -24.87  113.63
# 3        3  Cabo San Lucas      MX  2020-02-21 06:50:17  22.89 -109.91
# 4        4          Broome      US  2020-02-21 06:50:18  42.25  -75.83
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     62.55        22          34        9.19
# 1     57.20        62          75       17.22
# 2     87.80        62         100       20.80
# 3     70.00        56           0        6.82
# 4     15.80        92          90        2.86

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
temps
# Out:
# [62.55,
#  57.2,
#  87.8,
#  70.0,
#  15.8,
#  57.2,
#  85.86,
#  78.49,
#  18.0,
#  77.83,
#  32.0,
#  85.78,
#  0,
#  23.0,
#  81.05,
#  5.0,
#  69.8,
#  0,
#  28.4,
#  0,
#  62.6,
#  53.01,
#  77.74,
#  71.01,
#  82.4,
#  80.6,
#  73.31,
#  68.09,
#  84.2,
#  75.0,
#  0,
#  20.3,
#  50.0,
#  53.6,
#  17.06,
#  83.97,
#  57.99,
#  51.01,
#  78.8,
#  82.4,
#  80.71,
#  68.67,
#  74.95,
#  62.6,
#  0,
#  31.95,
#  73.99,
#  55.4,
#  37.4,
#  82.99,
#  66.88,
#  3.2,
#  71.6,
#  82.4,
#  57.2,
#  76.55,
#  71.6,
#  71.01,
#  21.2,
#  78.1,
#  43.0,
#  28.44,
#  93.99,
#  84.24,
#  69.37,
#  77.59,
#  24.78,
#  33.13,
#  24.01,
#  67.82,
#  81.55,
#  73.4,
#  73.2,
#  80.31,
#  69.76,
#  0,
#  50.0,
#  59.0,
#  58.71,
#  69.44,
#  35.01,
#  0,
#  68.5,
#  30.81,
#  93.2,
#  23.0,
#  75.2,
#  86.0,
#  75.0,
#  76.32,
#  75.24,
#  73.89,
#  77.0,
#  62.62,
#  56.39,
#  76.33,
#  68.02,
#  75.56,
#  35.6,
#  64.99,
#  55.49,
#  64.99,
#  23.4,
#  77.07,
#  87.19,
#  0,
#  0,
#  86.67,
#  39.2,
#  18.25,
#  81.18,
#  33.73,
#  79.84,
#  80.6,
#  69.8,
#  12.9,
#  33.01,
#  28.4,
#  95.0,
#  0,
#  54.0,
#  86.0,
#  15.01,
#  0,
#  79.14,
#  59.83,
#  68.0,
#  11.01,
#  78.8,
#  0,
#  10.56,
#  78.8,
#  39.2,
#  68.13,
#  66.92,
#  53.83,
#  69.01,
#  81.75,
#  69.75,
#  81.0,
#  73.0,
#  71.6,
#  27.97,
#  75.99,
#  51.01,
#  0,
#  26.49,
#  62.6,
#  66.47,
#  46.4,
#  0,
#  68.0,
#  71.01,
#  82.4,
#  12.2,
#  77.0,
#  22.33,
#  75.2,
#  23.47,
#  61.0,
#  44.6,
#  73.42,
#  75.2,
#  33.01,
#  82.4,
#  32.0,
#  57.2,
#  62.6,
#  81.57,
#  69.44,
#  75.2,
#  45.0,
#  9.0,
#  33.8,
#  20.35,
#  78.35,
#  68.0,
#  53.94,
#  19.4,
#  31.98,
#  64.4,
#  89.01,
#  85.12,
#  86.0,
#  82.33,
#  76.15,
#  78.8,
#  0,
#  27.0,
#  69.4,
#  52.12,
#  92.57,
#  86.0,
#  5.27,
#  35.01,
#  73.4,
#  45.0,
#  58.26,
#  60.06,
#  60.8,
#  28.4,
#  23.95,
#  10.99,
#  66.78,
#  50.07,
#  75.2,
#  83.26,
#  55.99,
#  64.2,
#  69.01,
#  14.58,
#  21.99,
#  30.88,
#  74.8,
#  55.53,
#  21.0,
#  69.8,
#  92.43,
#  24.8,
#  76.26,
#  57.99,
#  23.0,
#  69.24,
#  42.01,
#  75.99,
#  81.79,
#  54.55,
#  23.0,
#  91.4,
#  32.0,
#  68.27,
#  21.0,
#  42.44,
#  57.99,
#  29.77,
#  42.01,
#  63.52,
#  86.43,
#  0,
#  81.28,
#  32.77,
#  31.01,
#  48.0,
#  6.8,
#  0,
#  71.96,
#  67.33,
#  82.4,
#  68.56,
#  39.99,
#  6.55,
#  82.31,
#  73.4,
#  75.99,
#  57.99,
#  60.8,
#  0,
#  75.2,
#  33.8,
#  84.18,
#  69.33,
#  79.79,
#  60.8,
#  73.4,
#  21.51,
#  37.4,
#  55.4,
#  41.0,
#  48.0,
#  82.0,
#  1.4,
#  89.6,
#  69.8,
#  50.0,
#  70.9,
#  21.2,
#  80.6,
#  46.4,
#  17.6,
#  19.74,
#  73.58,
#  77.18,
#  37.4,
#  83.03,
#  60.8,
#  60.01,
#  81.14,
#  51.64,
#  69.12,
#  51.01,
#  0,
#  43.0,
#  94.42,
#  71.6,
#  58.37,
#  59.97,
#  33.8,
#  77.0,
#  80.6,
#  79.12,
#  53.73,
#  12.2,
#  68.59,
#  82.4,
#  49.33,
#  23.0,
#  55.4,
#  74.21,
#  72.9,
#  33.8,
#  19.2,
#  70.95,
#  67.01,
#  60.01,
#  28.4,
#  87.55,
#  76.68,
#  77.79,
#  79.86,
#  55.4,
#  0,
#  66.79,
#  65.95,
#  24.8,
#  87.8,
#  21.99,
#  75.16,
#  0,
#  68.0,
#  75.69,
#  64.94,
#  6.89,
#  55.4,
#  0,
#  0,
#  53.01,
#  76.89,
#  44.01,
#  92.77,
#  78.8,
#  64.8,
#  48.2,
#  55.29,
#  55.4,
#  66.2,
#  0,
#  39.2,
#  78.8,
#  59.0,
#  37.99,
#  84.76,
#  38.37,
#  75.78,
#  44.01,
#  72.61,
#  75.51,
#  52.29,
#  41.0,
#  72.1,
#  55.4,
#  48.2,
#  0,
#  56.46,
#  70.57,
#  86.04,
#  45.0,
#  100.4,
#  14.0,
#  18.0,
#  74.48,
#  19.4,
#  64.85,
#  26.6,
#  50.0,
#  74.26,
#  68.0,
#  48.29,
#  86.81,
#  20.53,
#  28.4,
#  78.01,
#  75.69,
#  19.49,
#  55.99,
#  79.0,
#  77.0,
#  50.0,
#  8.17,
#  71.01,
#  33.8,
#  53.71,
#  0,
#  57.0,
#  12.83,
#  83.86,
#  12.99,
#  83.61,
#  64.0,
#  26.6,
#  75.47,
#  23.0,
#  83.25,
#  53.49,
#  68.88,
#  85.3,
#  54.66,
#  67.46,
#  70.09,
#  27.66,
#  50.0,
#  77.0,
#  83.17,
#  91.4,
#  77.0,
#  77.07,
#  33.01,
#  37.0,
#  66.2,
#  64.4,
#  76.06,
#  37.4,
#  89.6,
#  30.2,
#  60.8,
#  82.54,
#  43.83,
#  19.0,
#  84.63,
#  30.88,
#  80.17,
#  39.99,
#  76.05,
#  39.0,
#  57.2,
#  77.0,
#  16.93,
#  86.04,
#  86.0,
#  55.0,
#  87.8,
#  71.1,
#  89.6,
#  70.48,
#  38.61,
#  66.79,
#  12.2,
#  21.2,
#  0,
#  36.73,
#  13.21,
#  76.62,
#  95.54,
#  91.4,
#  60.01,
#  0,
#  79.11,
#  50.0,
#  82.31,
#  16.79,
#  71.28,
#  32.0,
#  76.71,
#  55.4,
#  30.22,
#  42.01,
#  78.8,
#  55.24,
#  84.2,
#  82.4,
#  41.0,
#  78.78,
#  83.05,
#  75.85,
#  83.17,
#  50.0,
#  51.8,
#  78.76,
#  77.0,
#  31.05,
#  32.25,
#  44.6,
#  10.4,
#  70.07,
#  89.6,
#  77.74,
#  10.0,
#  81.16,
#  37.56,
#  32.0,
#  42.8,
#  41.0,
#  75.99,
#  0,
#  79.7,
#  57.2,
#  80.6,
#  78.85,
#  0,
#  69.35,
#  68.05,
#  47.7,
#  82.69,
#  82.65,
#  28.4,
#  62.6,
#  32.0,
#  79.0,
#  82.0,
#  6.8,
#  32.0,
#  44.01,
#  76.5,
#  41.7,
#  5.0,
#  29.43,
#  80.6,
#  88.43,
#  5.99,
#  66.24,
#  33.8,
#  46.0,
#  55.99,
#  0,
#  84.2,
#  73.24,
#  46.4,
#  0,
#  82.78,
#  75.0,
#  71.29,
#  28.0,
#  29.57,
#  13.3,
#  77.32,
#  86.0,
#  73.4,
#  37.99,
#  21.2,
#  80.17,
#  11.43,
#  82.4,
#  28.99,
#  10.8,
#  68.27,
#  24.01,
#  53.6,
#  37.4,
#  84.06,
#  67.33,
#  43.81,
#  54.0,
#  27.12,
#  51.78,
#  72.21,
#  77.27,
#  52.0,
#  73.89]

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=temps, dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
cloudiness = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=cloudiness, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
windspeed = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=windspeed, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date    Lat     Lng  \
# 2         2       Carnarvon      AU  2020-02-21 06:50:17 -24.87  113.63
# 6         6         Palauig      PH  2020-02-21 06:50:18  15.44  119.90
# 7         7         Rikitea      PF  2020-02-21 06:50:18 -23.12 -134.97
# 9         9     Bandarbeyla      SO  2020-02-21 06:50:19   9.49   50.81
# 11       11           Buala      SB  2020-02-21 06:50:20  -8.14  159.59
# 14       14           Kimbe      PG  2020-02-21 06:50:20  -5.55  150.14
# 22       22    Puerto Ayora      EC  2020-02-21 06:50:23  -0.74  -90.35
# 24       24          Avarua      CK  2020-02-21 06:50:24 -21.21 -159.78
# 25       25       Guarapari      BR  2020-02-21 06:50:24 -20.67  -40.50
# 28       28  Saint-Philippe      RE  2020-02-21 06:47:51 -21.36   55.77
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 2      87.80        62         100       20.80
# 6      85.86        41           4        3.91
# 7      78.49        75          42       13.85
# 9      77.83        72          52        9.62
# 11     85.78        68         100        8.05
# 14     81.05        84          70        5.21
# 22     77.74        88          77        8.50
# 24     82.40        88         100       10.29
# 25     80.60        74           4       10.29
# 28     84.20        69          75       24.16

# %%
preferred_cities_df.count()
# Out:
# City_ID       157
# City          157
# Country       157
# Date          157
# Lat           157
# Lng           157
# Max Temp      157
# Humidity      157
# Cloudiness    157
# Wind Speed    157
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp    Lat     Lng Hotel Name
# 2        Carnarvon      AU     87.80 -24.87  113.63
# 6          Palauig      PH     85.86  15.44  119.90
# 7          Rikitea      PF     78.49 -23.12 -134.97
# 9      Bandarbeyla      SO     77.83   9.49   50.81
# 11           Buala      SB     85.78  -8.14  159.59
# 14           Kimbe      PG     81.05  -5.55  150.14
# 22    Puerto Ayora      EC     77.74  -0.74  -90.35
# 24          Avarua      CK     82.40 -21.21 -159.78
# 25       Guarapari      BR     80.60 -20.67  -40.50
# 28  Saint-Philippe      RE     84.20 -21.36   55.77

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    # Grab the first hotel from the results and store the name.
    try:
       hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
     print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

# %%
hotels
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': 5.2609021,
#      'lng': -0.7588615999999999},
#     'viewport': {'northeast': {'lat': 5.262856880291502, 'lng': -0.75599255},
#      'southwest': {'lat': 5.260158919708497, 'lng': -0.7598179499999999}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '84cdfbec46b16f0bc3fe5b1a7b60ee44766e6501',
#    'name': 'Spanish Villa',
#    'photos': [{'height': 4864,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118027234293654633608">Sampson Attuquaye</a>'],
#      'photo_reference': 'CmRaAAAAh14mI8YpyKpO0J6BxQk3Maw58iMW3YD5edLinGCGDDHwKda5TEWuYY6JND0DcSEdK8mlpv12QITsxGLmU38WuBlNVzxfMPIcYqE6NsND8pkGgGlMaOjqmJ_mjAq4_Z4XEhDCPtglRBGHNGwouXII1kL9GhQl5VQOX2OHAzHOispQiclFKXUyuw',
#      'width': 2736}],
#    'place_id': 'ChIJP2YiNIQ63g8R-pxhUkeSStw',
#    'plus_code': {'compound_code': '766R+9F Mumford, Ghana',
#     'global_code': '6CQX766R+9F'},
#    'rating': 4,
#    'reference': 'ChIJP2YiNIQ63g8R-pxhUkeSStw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 27,
#    'vicinity': 'Mumford'},
#   {'geometry': {'location': {'lat': 5.2607038, 'lng': -0.7594091},
#     'viewport': {'northeast': {'lat': 5.263031049999999, 'lng': -0.7586168},
#      'southwest': {'lat': 5.259928049999999, 'lng': -0.7617860000000001}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '6782018f1b56842b3119d6c0d83601ecb81ace04',
#    'name': 'Peace Guest House',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104023947852212797601">Ebenezer White Nyarkoh</a>'],
#      'photo_reference': 'CmRaAAAA1MyDJ0DVUbMBgEyLFXyC6Z4oq1j_38MhW4izMQQL55LQd-wR3qRjTQqhBMCzBndojLpno3OWtbqCcWFAbQGajTbaLbX_cZWX8DflkF5ur9L7Agzm71uOlgs1Ovq5s-A7EhA0bZB1paIG4N_L3v-fKJYxGhRxd3GaM-DKKjjhtKJFKie-t6xNPQ',
#      'width': 1920}],
#    'place_id': 'ChIJkYO_K5s73g8RxNsywGidllI',
#    'plus_code': {'compound_code': '766R+76 Mumford, Ghana',
#     'global_code': '6CQX766R+76'},
#    'rating': 4.5,
#    'reference': 'ChIJkYO_K5s73g8RxNsywGidllI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Mumford'},
#   {'geometry': {'location': {'lat': 5.2705834, 'lng': -0.7508857999999999},
#     'viewport': {'northeast': {'lat': 5.272201530291503,
#       'lng': -0.7498874697084981},
#      'southwest': {'lat': 5.269503569708498, 'lng': -0.7525854302915022}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '404b57ed395acd9f5173a53e0de90ffbf509abe1',
#    'name': 'Mumford Atlantic Resort',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 520,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116226311088439836638">Funny Playz</a>'],
#      'photo_reference': 'CmRaAAAAN_kC00APOuOwvr0fTt0TFWjcXiD6Sb3T2Sv7kx20QtVZ7jITYSROoRhSb6IvZsY1awMlAmlcnUfBH6Ncmyrfuzzzx7tyewcEa2KagRj2mf65hdy2klGTZZ2p3Id8oVPiEhBHdcYRIdD8FXlNHCtakox8GhQbAkRlL2UTcRJWBzPNnomQlnwSkA',
#      'width': 960}],
#    'place_id': 'ChIJg_37_4Aw3g8RENYApdFuODo',
#    'plus_code': {'compound_code': '76CX+6J Mumford, Ghana',
#     'global_code': '6CQX76CX+6J'},
#    'rating': 3.7,
#    'reference': 'ChIJg_37_4Aw3g8RENYApdFuODo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 12,
#    'vicinity': 'Mumford'},
#   {'geometry': {'location': {'lat': 5.2749888, 'lng': -0.75064},
#     'viewport': {'northeast': {'lat': 5.276338430291503,
#       'lng': -0.7494316197084979},
#      'southwest': {'lat': 5.273640469708498, 'lng': -0.752129580291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '7a72e5a722a19b4726f81771508b9cd6567238b5',
#    'name': 'JKB Guest House',
#    'place_id': 'ChIJK-vRs4Mw3g8R5MQsMpZXVSQ',
#    'plus_code': {'compound_code': '76FX+XP Mumford, Ghana',
#     'global_code': '6CQX76FX+XP'},
#    'rating': 4,
#    'reference': 'ChIJK-vRs4Mw3g8R5MQsMpZXVSQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 7,
#    'vicinity': 'Apam junction, near A&C school park, Apam'},
#   {'geometry': {'location': {'lat': 5.2766867, 'lng': -0.7486018},
#     'viewport': {'northeast': {'lat': 5.278117030291503,
#       'lng': -0.7470941197084979},
#      'southwest': {'lat': 5.275419069708498, 'lng': -0.749792080291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'b1d0a3b089c9e41fa1a42dc605c8b70b55ffd280',
#    'name': 'Lymmbah Guesthouse',
#    'photos': [{'height': 4128,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114377445489337883051">Fiifi Sagoe</a>'],
#      'photo_reference': 'CmRaAAAAqljKS74pRpD_kHLkXLnrOmJw9xwhr6F3b5KrTHl8M_LythEvAOW-B-XJEL5pu9W1PQQ37sUhTNfaBKF2-6x9lS1kLLTKmj3VGsoAqdOrlMMtSSizlM8mCysFdDilnd9qEhDuVwsmAFdqsHkr9J7jQ1XtGhQ1OXqVEpzBahgH9gUbimMq1FwH8Q',
#      'width': 2322}],
#    'place_id': 'ChIJcfdnYoMw3g8RID6XYVtk-NE',
#    'plus_code': {'compound_code': '77G2+MH Mumford, Ghana',
#     'global_code': '6CQX77G2+MH'},
#    'rating': 3.3,
#    'reference': 'ChIJcfdnYoMw3g8RID6XYVtk-NE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 7,
#    'vicinity': 'Apam junction drive straight and ask for Nsu Etsi, Apam'},
#   {'geometry': {'location': {'lat': 5.2841291, 'lng': -0.7383316000000001},
#     'viewport': {'northeast': {'lat': 5.285511730291502,
#       'lng': -0.736947169708498},
#      'southwest': {'lat': 5.282813769708498, 'lng': -0.7396451302915021}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '228f52691a03815070ca210574304ebe2a32f374',
#    'name': 'Eliza Guest House',
#    'photos': [{'height': 768,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115278881590290050884">JERRY BABATUNDE</a>'],
#      'photo_reference': 'CmRaAAAAyOuD_L2YFuUYJajeF8TEwAeML9nh3SzUflnCtmJqtB0TopovorybXrqesqWJGRLBH6zi-dig8woV-qGUAxUoQkgQWVTJIxPFYli-oS3IZHt2Lor1SmxdjOWE2sfbVcqSEhBZV33LO8JlidXJUlUVwW05GhQjo0Rd2e50kMmwPIV0x5ppKKeoJg',
#      'width': 1024}],
#    'place_id': 'ChIJ29sRD5Qw3g8RnflK83hnFZM',
#    'plus_code': {'compound_code': '77M6+MM Apam, Ghana',
#     'global_code': '6CQX77M6+MM'},
#    'rating': 3.8,
#    'reference': 'ChIJ29sRD5Qw3g8RnflK83hnFZM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 32,
#    'vicinity': '2 Mamtram Street Adjacent Apam Apostolic Church, Accra'},
#   {'geometry': {'location': {'lat': 5.2941315, 'lng': -0.7390245},
#     'viewport': {'northeast': {'lat': 5.295571330291502,
#       'lng': -0.7375048197084979},
#      'southwest': {'lat': 5.292873369708498, 'lng': -0.740202780291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/camping-71.png',
#    'id': '0ad22e4944d0658f2b331bc0dcd8cd66981f0c79',
#    'name': 'BrEssler Ark Campsite',
#    'place_id': 'ChIJpRZlL60x3g8R_qU9ACe34WI',
#    'plus_code': {'compound_code': '77V6+M9 Apam, Ghana',
#     'global_code': '6CQX77V6+M9'},
#    'reference': 'ChIJpRZlL60x3g8R_qU9ACe34WI',
#    'scope': 'GOOGLE',
#    'types': ['campground',
#     'lodging',
#     'park',
#     'point_of_interest',
#     'establishment'],
#    'vicinity': 'Abrekum Apam beach, Apam'},
#   {'geometry': {'location': {'lat': 5.2941315, 'lng': -0.7390245},
#     'viewport': {'northeast': {'lat': 5.295571330291502,
#       'lng': -0.7375048197084979},
#      'southwest': {'lat': 5.292873369708498, 'lng': -0.740202780291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'e47ed2afdcf6ea9bf68b8fd476777c6faca2ebcc',
#    'name': 'ABREKUM',
#    'place_id': 'ChIJ7wsHjw8x3g8RBWeIjLEm5uM',
#    'plus_code': {'compound_code': '77V6+M9 Apam, Ghana',
#     'global_code': '6CQX77V6+M9'},
#    'rating': 4.3,
#    'reference': 'ChIJ7wsHjw8x3g8RBWeIjLEm5uM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'ABREKUM, Apam'}],
#  'status': 'OK'}

# %%
len(hotels["results"])
# Out:
# 0

# %%
hotel_df.head(10)
# Out:
#               City Country  Max Temp    Lat     Lng  \
# 2        Carnarvon      AU     87.80 -24.87  113.63
# 6          Palauig      PH     85.86  15.44  119.90
# 7          Rikitea      PF     78.49 -23.12 -134.97
# 9      Bandarbeyla      SO     77.83   9.49   50.81
# 11           Buala      SB     85.78  -8.14  159.59
# 14           Kimbe      PG     81.05  -5.55  150.14
# 22    Puerto Ayora      EC     77.74  -0.74  -90.35
# 24          Avarua      CK     82.40 -21.21 -159.78
# 25       Guarapari      BR     80.60 -20.67  -40.50
# 28  Saint-Philippe      RE     84.20 -21.36   55.77
#
#                       Hotel Name
# 2          Hospitality Carnarvon
# 6                Myhousebythesea
# 7                 Pension Maro'i
# 9             REER XOOSHLE GROUP
# 11          Maringe Lagoon Lodge
# 14               Kimbe Bay Hotel
# 22     Finch Bay Galapagos Hotel
# 24                  Paradise Inn
# 25            Hotel Porto do Sol
# 28  Chambres d'hôte "La Trinité"

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
